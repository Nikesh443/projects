# %% [markdown]
# import warnings as war
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# war.filterwarnings("ignore")
# sns.set_theme(color_codes=True)
# from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("C:\\Users\\pc\\Documents\\telecom_customer_churn.csv")
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %% [markdown]
# df.columns

# %%
df.info
# Out:
# <bound method DataFrame.info of      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
# ...

# %%
df.drop(columns=['Customer ID','Zip Code'], inplace=True)

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents          City   Latitude  \
# 0     Female   37     Yes                     0  Frazier Park  34.827662
# 1       Male   46      No                     0      Glendale  34.162515
# 2       Male   50      No                     0    Costa Mesa  33.645672
# 3       Male   78     Yes                     0      Martinez  38.014457
# 4     Female   75     Yes                     0     Camarillo  34.227846
# ...      ...  ...     ...                   ...           ...        ...
# 7038  Female   20      No                     0       La Mesa  32.759327
# 7039    Male   40     Yes                     0     Riverbank  37.734971
# 7040    Male   22      No                     0           Elk  39.108252
# 7041    Male   21     Yes                     0  Solana Beach  33.001813
# 7042    Male   36     Yes                     0   Sierra City  39.600599
#
#        Longitude  Number of Referrals  Tenure in Months    Offer  ...  \
# ...

# %%
df.isna().sum()
# Out:
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# Streaming TV                         1526
# Streaming Movies                     1526
# ...

# %%
df.dtypes
# Out:
# Gender                                object
# Age                                    int64
# Married                               object
# Number of Dependents                   int64
# City                                  object
# Latitude                             float64
# Longitude                            float64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Phone Service                         object
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                        object
# Internet Service                      object
# Internet Type                         object
# Avg Monthly GB Download              float64
# Online Security                       object
# Online Backup                         object
# Device Protection Plan                object
# Premium Tech Support                  object
# Streaming TV                          object
# ...

# %%
df.select_dtypes(include='object').nunique()
# Out:
# Gender                       2
# Married                      2
# City                      1106
# Offer                        5
# Phone Service                2
# Multiple Lines               2
# Internet Service             2
# Internet Type                3
# Online Security              2
# Online Backup                2
# Device Protection Plan       2
# Premium Tech Support         2
# Streaming TV                 2
# Streaming Movies             2
# Streaming Music              2
# Unlimited Data               2
# Contract                     3
# Paperless Billing            2
# Payment Method               3
# Customer Status              3
# Churn Category               5
# Churn Reason                20
# dtype: int64

# %%
df.drop(columns=['City'],inplace=True)
# There are many unique values in column city if we replace with 1,2,3,4 also it will not sufficient

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents   Latitude   Longitude  \
# 0     Female   37     Yes                     0  34.827662 -118.999073
# 1       Male   46      No                     0  34.162515 -118.203869
# 2       Male   50      No                     0  33.645672 -117.922613
# 3       Male   78     Yes                     0  38.014457 -122.115432
# 4     Female   75     Yes                     0  34.227846 -119.079903
# ...      ...  ...     ...                   ...        ...         ...
# 7038  Female   20      No                     0  32.759327 -116.997260
# 7039    Male   40     Yes                     0  37.734971 -120.954271
# 7040    Male   22      No                     0  39.108252 -123.645121
# 7041    Male   21     Yes                     0  33.001813 -117.263628
# 7042    Male   36     Yes                     0  39.600599 -120.636358
#
#       Number of Referrals  Tenure in Months    Offer Phone Service  ...  \
# ...

# %% [markdown]
# ## Exploratory Data analysis

# %%
N=dict(df.dtypes)
cat=[i for i in N if N[i]=='object']
cat
# Out:
# ['Gender',
#  'Married',
#  'Offer',
#  'Phone Service',
#  'Multiple Lines',
#  'Internet Service',
#  'Internet Type',
#  'Online Security',
#  'Online Backup',
#  'Device Protection Plan',
#  'Premium Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Streaming Music',
#  'Unlimited Data',
#  'Contract',
#  'Paperless Billing',
#  'Payment Method',
#  'Customer Status',
#  'Churn Category',
#  'Churn Reason']

# %%
N=dict(df.dtypes)
num=[i for i in N if N[i]!='object']
num
# Out:
# ['Age',
#  'Number of Dependents',
#  'Latitude',
#  'Longitude',
#  'Number of Referrals',
#  'Tenure in Months',
#  'Avg Monthly Long Distance Charges',
#  'Avg Monthly GB Download',
#  'Monthly Charge',
#  'Total Charges',
#  'Total Refunds',
#  'Total Extra Data Charges',
#  'Total Long Distance Charges',
#  'Total Revenue']

# %%
print(f'The length of cat columns is {len(cat)}')
print(f'The length of cat columns is {len(num)}')
# Out:
# The length of cat columns is 21
# The length of cat columns is 14

# %%
cat=df.select_dtypes(include='object').columns.tolist()
len(cat)
# Out:
# 21

# %%
num=df.select_dtypes(include=['int','float']).columns.tolist()
len(num)
# Out:
# 14

# %%
df.describe()
# Out:
#                Age  Number of Dependents     Latitude    Longitude  \
# count  7043.000000           7043.000000  7043.000000  7043.000000
# mean     46.509726              0.468692    36.197455  -119.756684
# std      16.750352              0.962802     2.468929     2.154425
# min      19.000000              0.000000    32.555828  -124.301372
# 25%      32.000000              0.000000    33.990646  -121.788090
# 50%      46.000000              0.000000    36.205465  -119.595293
# 75%      60.000000              0.000000    38.161321  -117.969795
# max      80.000000              9.000000    41.962127  -114.192901
#
#        Number of Referrals  Tenure in Months  \
# count          7043.000000       7043.000000
# mean              1.951867         32.386767
# std               3.001199         24.542061
# min               0.000000          1.000000
# 25%               0.000000          9.000000
# 50%               0.000000         29.000000
# ...

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents   Latitude   Longitude  \
# 0     Female   37     Yes                     0  34.827662 -118.999073
# 1       Male   46      No                     0  34.162515 -118.203869
# 2       Male   50      No                     0  33.645672 -117.922613
# 3       Male   78     Yes                     0  38.014457 -122.115432
# 4     Female   75     Yes                     0  34.227846 -119.079903
# ...      ...  ...     ...                   ...        ...         ...
# 7038  Female   20      No                     0  32.759327 -116.997260
# 7039    Male   40     Yes                     0  37.734971 -120.954271
# 7040    Male   22      No                     0  39.108252 -123.645121
# 7041    Male   21     Yes                     0  33.001813 -117.263628
# 7042    Male   36     Yes                     0  39.600599 -120.636358
#
#       Number of Referrals  Tenure in Months    Offer Phone Service  ...  \
# ...

# %%
df['Customer Status'].unique()
# Out:
# array(['Stayed', 'Churned', 'Joined'], dtype=object)

# %%
df['Customer Status']=df['Customer Status'].replace('Joined','Stayed')
df['Customer Status'].unique()
# Out:
# array(['Stayed', 'Churned'], dtype=object)

# %%
df['Customer Status'].value_counts()
# Out:
# Customer Status
# Stayed     5174
# Churned    1869
# Name: count, dtype: int64

# %%
cat_col=df.select_dtypes(include="object").columns.tolist()
for col in cat_col:
    print(f'{col}={df[col].nunique()}')
# Out:
# Gender=2
# Married=2
# Offer=5
# Phone Service=2
# Multiple Lines=2
# Internet Service=2
# Internet Type=3
# Online Security=2
# Online Backup=2
# Device Protection Plan=2
# Premium Tech Support=2
# Streaming TV=2
# Streaming Movies=2
# Streaming Music=2
# Unlimited Data=2
# Contract=3
# Paperless Billing=2
# Payment Method=3
# Customer Status=2
# Churn Category=5
# Churn Reason=20

# %%
df.isna().sum()
# Out:
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# Streaming TV                         1526
# Streaming Movies                     1526
# Streaming Music                      1526
# ...

# %%
df.drop(columns=['Churn Category','Churn Reason'],inplace=True)
df
# Out:
#       Gender  Age Married  Number of Dependents   Latitude   Longitude  \
# 0     Female   37     Yes                     0  34.827662 -118.999073
# 1       Male   46      No                     0  34.162515 -118.203869
# 2       Male   50      No                     0  33.645672 -117.922613
# 3       Male   78     Yes                     0  38.014457 -122.115432
# 4     Female   75     Yes                     0  34.227846 -119.079903
# ...      ...  ...     ...                   ...        ...         ...
# 7038  Female   20      No                     0  32.759327 -116.997260
# 7039    Male   40     Yes                     0  37.734971 -120.954271
# 7040    Male   22      No                     0  39.108252 -123.645121
# 7041    Male   21     Yes                     0  33.001813 -117.263628
# 7042    Male   36     Yes                     0  39.600599 -120.636358
#
#       Number of Referrals  Tenure in Months    Offer Phone Service  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
check_missing=df.isnull().sum()*100/df.shape[0]
check_missing[check_missing>0].sort_values(ascending=False)
# Out:
# Offer                                55.047565
# Internet Type                        21.666903
# Avg Monthly GB Download              21.666903
# Online Security                      21.666903
# Online Backup                        21.666903
# Device Protection Plan               21.666903
# Premium Tech Support                 21.666903
# Streaming TV                         21.666903
# Streaming Movies                     21.666903
# Streaming Music                      21.666903
# Unlimited Data                       21.666903
# Avg Monthly Long Distance Charges     9.683374
# Multiple Lines                        9.683374
# dtype: float64

# %%
df.drop('Offer',axis=1,inplace=True)

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents   Latitude   Longitude  \
# 0     Female   37     Yes                     0  34.827662 -118.999073
# 1       Male   46      No                     0  34.162515 -118.203869
# 2       Male   50      No                     0  33.645672 -117.922613
# 3       Male   78     Yes                     0  38.014457 -122.115432
# 4     Female   75     Yes                     0  34.227846 -119.079903
# ...      ...  ...     ...                   ...        ...         ...
# 7038  Female   20      No                     0  32.759327 -116.997260
# 7039    Male   40     Yes                     0  37.734971 -120.954271
# 7040    Male   22      No                     0  39.108252 -123.645121
# 7041    Male   21     Yes                     0  33.001813 -117.263628
# 7042    Male   36     Yes                     0  39.600599 -120.636358
#
#       Number of Referrals  Tenure in Months Phone Service  \
# ...

# %%
check_missing=df.isnull().sum()*100/df.shape[0]
check_missing[check_missing>0].sort_values(ascending=False)
# Out:
# Internet Type                        21.666903
# Avg Monthly GB Download              21.666903
# Online Security                      21.666903
# Online Backup                        21.666903
# Device Protection Plan               21.666903
# Premium Tech Support                 21.666903
# Streaming TV                         21.666903
# Streaming Movies                     21.666903
# Streaming Music                      21.666903
# Unlimited Data                       21.666903
# Avg Monthly Long Distance Charges     9.683374
# Multiple Lines                        9.683374
# dtype: float64

# %%
subset_cols=['Internet Type','Avg Monthly GB Download','Online Security','Online Backup','Device Protection Plan','Premium Tech Support',
            'Streaming TV','Streaming Movies','Unlimited Data']
df.dropna(subset=subset_cols,inplace=True)

# %%
subset_columns=['Avg Monthly Long Distance Charges','Multiple Lines']
df.dropna(subset=subset_columns,inplace=True)

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents   Latitude   Longitude  \
# 0     Female   37     Yes                     0  34.827662 -118.999073
# 1       Male   46      No                     0  34.162515 -118.203869
# 2       Male   50      No                     0  33.645672 -117.922613
# 3       Male   78     Yes                     0  38.014457 -122.115432
# 4     Female   75     Yes                     0  34.227846 -119.079903
# ...      ...  ...     ...                   ...        ...         ...
# 7036  Female   53      No                     0  36.807595 -118.901544
# 7038  Female   20      No                     0  32.759327 -116.997260
# 7039    Male   40     Yes                     0  37.734971 -120.954271
# 7040    Male   22      No                     0  39.108252 -123.645121
# 7041    Male   21     Yes                     0  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months Phone Service  \
# ...

# %%
df['Customer Status'].value_counts()
# Out:
# Customer Status
# Stayed     3249
# Churned    1586
# Name: count, dtype: int64

# %% [markdown]
# ## Label Encoding: For cat into num

# %%
for col in df.select_dtypes(include='object').columns:
    print(f'{col}:{df[col].unique()}')
# Out:
# Gender:['Female' 'Male']
# Married:['Yes' 'No']
# Phone Service:['Yes']
# Multiple Lines:['No' 'Yes']
# Internet Service:['Yes']
# Internet Type:['Cable' 'Fiber Optic' 'DSL']
# Online Security:['No' 'Yes']
# Online Backup:['Yes' 'No']
# Device Protection Plan:['No' 'Yes']
# Premium Tech Support:['Yes' 'No']
# Streaming TV:['Yes' 'No']
# Streaming Movies:['No' 'Yes']
# Streaming Music:['No' 'Yes']
# Unlimited Data:['Yes' 'No']
# Contract:['One Year' 'Month-to-Month' 'Two Year']
# Paperless Billing:['Yes' 'No']
# Payment Method:['Credit Card' 'Bank Withdrawal' 'Mailed Check']
# Customer Status:['Stayed' 'Churned']

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for col in df.select_dtypes(include='object').columns:
    LE.fit(df[col].unique())
    df[col]=LE.transform(df[col])
    print(f'{col}:{df[col].unique()}')
# Out:
# Gender:[0 1]
# Married:[1 0]
# Phone Service:[0]
# Multiple Lines:[0 1]
# Internet Service:[0]
# Internet Type:[0 2 1]
# Online Security:[0 1]
# Online Backup:[1 0]
# Device Protection Plan:[0 1]
# Premium Tech Support:[1 0]
# Streaming TV:[1 0]
# Streaming Movies:[0 1]
# Streaming Music:[0 1]
# Unlimited Data:[1 0]
# Contract:[1 0 2]
# Paperless Billing:[1 0]
# Payment Method:[1 0 2]
# Customer Status:[1 0]

# %%
df
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0          0   37        1                     0  34.827662 -118.999073
# 1          1   46        0                     0  34.162515 -118.203869
# 2          1   50        0                     0  33.645672 -117.922613
# 3          1   78        1                     0  38.014457 -122.115432
# 4          0   75        1                     0  34.227846 -119.079903
# ...      ...  ...      ...                   ...        ...         ...
# 7036       0   53        0                     0  36.807595 -118.901544
# 7038       0   20        0                     0  32.759327 -116.997260
# 7039       1   40        1                     0  37.734971 -120.954271
# 7040       1   22        0                     0  39.108252 -123.645121
# 7041       1   21        1                     0  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months  Phone Service  \
# ...

# %%
plt.figure(figsize=(40,32))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# We have to remove intenet service and phone service because there is zero correlation
df.drop(columns=['Internet Service','Phone Service'],inplace=True)
df
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0          0   37        1                     0  34.827662 -118.999073
# 1          1   46        0                     0  34.162515 -118.203869
# 2          1   50        0                     0  33.645672 -117.922613
# 3          1   78        1                     0  38.014457 -122.115432
# 4          0   75        1                     0  34.227846 -119.079903
# ...      ...  ...      ...                   ...        ...         ...
# 7036       0   53        0                     0  36.807595 -118.901544
# 7038       0   20        0                     0  32.759327 -116.997260
# 7039       1   40        1                     0  37.734971 -120.954271
# 7040       1   22        0                     0  39.108252 -123.645121
# 7041       1   21        1                     0  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months  \
# 0                       2                 9
# ...

# %%
df.to_csv("preprocessed_data.csv",index=False)

# %% [markdown]
# ## Model development

# %%
df=pd.read_csv("preprocessed_data.csv")
df
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0          0   37        1                     0  34.827662 -118.999073
# 1          1   46        0                     0  34.162515 -118.203869
# 2          1   50        0                     0  33.645672 -117.922613
# 3          1   78        1                     0  38.014457 -122.115432
# 4          0   75        1                     0  34.227846 -119.079903
# ...      ...  ...      ...                   ...        ...         ...
# 4830       0   53        0                     0  36.807595 -118.901544
# 4831       0   20        0                     0  32.759327 -116.997260
# 4832       1   40        1                     0  37.734971 -120.954271
# 4833       1   22        0                     0  39.108252 -123.645121
# 4834       1   21        1                     0  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months  \
# 0                       2                 9
# ...

# %%
X=df.drop('Customer Status', axis=1)
y=df['Customer Status']

# %%
X.head()
# Out:
#    Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0       0   37        1                     0  34.827662 -118.999073
# 1       1   46        0                     0  34.162515 -118.203869
# 2       1   50        0                     0  33.645672 -117.922613
# 3       1   78        1                     0  38.014457 -122.115432
# 4       0   75        1                     0  34.227846 -119.079903
#
#    Number of Referrals  Tenure in Months  Avg Monthly Long Distance Charges  \
# 0                    2                 9                              42.39
# 1                    0                 9                              10.69
# 2                    0                 4                              33.65
# 3                    1                13                              27.82
# 4                    3                 3                               7.38
#
#    Multiple Lines  ...  Unlimited Data  Contract  Paperless Billing  \
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Customer Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3868, 29)
# (3868,)
# (967, 29)
# (967,)

# %%
from scipy import stats
# Define the columns for which you want to remove outliers
columns=["Number of Dependents","Avg Monthly GB Download","Total Refunds","Total Extra Data Charges",
        "Total Long Distance Charges","Total Revenue"]
# calculate the z_scores for the columns in the training data
z_scores=np.abs(stats.zscore(X_train[columns]))
# Set a threshold value for a outlier detection eg:3
threshold=3

# Find the indices of outliers based on threshold
outlier_indices=np.where(z_scores > threshold)[0]
# Remove the outliers from the training data

X_train=X_train.drop(X_train.index[outlier_indices])
y_train=y_train.drop(y_train.index[outlier_indices])

# %%
X_train.head()
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 432        1   31        0                     0  33.977468 -118.445475
# 4135       1   21        1                     0  33.723579 -118.005441
# 289        1   41        0                     1  34.007353 -118.033683
# 2692       0   42        1                     0  37.441931 -121.878502
# 4110       0   32        1                     0  33.324900 -114.758334
#
#       Number of Referrals  Tenure in Months  \
# 432                     0                56
# 4135                    4                66
# 289                     0                12
# 2692                    1                69
# 4110                    0                57
#
#       Avg Monthly Long Distance Charges  Multiple Lines  ...  Unlimited Data  \
# 432                               37.99               1  ...               1
# 4135                               7.67               1  ...               1
# ...

# %% [markdown]
# ## Without Hyperparameter tuning

# %%
# we are not providing any parameters we are using the default parameters

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
model=dtree.fit(X_train,y_train)
model
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([1, 0, 1, 0, 1, 0, 1, 1, 0, 1], dtype=int64)

# %%
y_test[:10]
# Out:
# 3317    0
# 2533    1
# 1041    1
# 3307    0
# 4401    0
# 3898    0
# 1926    0
# 3094    0
# 764     0
# 3447    1
# Name: Customer Status, dtype: int64

# %%
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error,mean_absolute_percentage_error,root_mean_squared_error,mean_squared_error

# %%
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7518097207859359

# %%
import math

# %%
RMSE=math.sqrt(mean_squared_error(y_test,y_pred))
RMSE
# Out:
# 0.4981869922168423

# %%
print(f'The accuracy is {acc}')
print(f'The r2 score is {r2_score(y_test,y_pred)}')
print(f'The mean squared error is {mean_squared_error(y_test,y_pred)}')
print(f'The mean absolute error is {mean_absolute_error(y_test,y_pred)}')
print(f'The mae percentage is {mean_absolute_percentage_error(y_test,y_pred)}')
print(f'The root mean squared error is {RMSE}')
# Out:
# The accuracy is 0.7518097207859359
# The r2 score is -0.10729417153326448
# The mean squared error is 0.2481902792140641
# The mean absolute error is 0.2481902792140641
# The mae percentage is 526273793063977.3
# The root mean squared error is 0.4981869922168423

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[215, 113],
#        [127, 512]], dtype=int64)

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_pred).ravel()  # python will take opposite of what we read in theory
print(tn,fp,fn,tp)
# Out:
# 215 113 127 512

# %%
(tn+tp)/(tn+tp+fp+fn)  # accuracy is valid
# Out:
# 0.7518097207859359

# %%
precision=tp/(tp+fp)
recall=tp/(tp+fn)
f1=(2*precision*recall)/(precision+recall)

# %%
print(precision,recall,f1)
# Out:
# 0.8192 0.8012519561815337 0.8101265822784811

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred)
# Out:
# 0.8192

# %%
recall_score(y_test,y_pred)
# Out:
# 0.8012519561815337

# %%
f1_score(y_test,y_pred)
# Out:
# 0.810126582278481

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,roc_auc_score,RocCurveDisplay,roc_curve,auc
cmt=confusion_matrix(y_test,y_pred)
ConfusionMatrixDisplay(cmt,
                      display_labels=[False,True]).plot()
plt.grid(False)

# %%
TPR=tp/tp+fp

# %%
TPR
# Out:
# 114.0

# %%
FPR=fp/fp+tp

# %%
FPR
# Out:
# 513.0

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
roc_auc=auc(fpr,tpr)
plt.plot(fpr,tpr)

# %%
#display.plot()

# %%
y_pred_prob=model.predict_proba(X_test)[:,1] 
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
# True positives
#col=1  #col=2
#col=1 related 
#[0.,1,]
# class 0 and class 1
# we need to extreact only class 1 prob

# %% [markdown]
# ## logistic regression

# %%
df=pd.read_csv("preprocessed_data.csv")
df
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0          0   37        1                     0  34.827662 -118.999073
# 1          1   46        0                     0  34.162515 -118.203869
# 2          1   50        0                     0  33.645672 -117.922613
# 3          1   78        1                     0  38.014457 -122.115432
# 4          0   75        1                     0  34.227846 -119.079903
# ...      ...  ...      ...                   ...        ...         ...
# 4830       0   53        0                     0  36.807595 -118.901544
# 4831       0   20        0                     0  32.759327 -116.997260
# 4832       1   40        1                     0  37.734971 -120.954271
# 4833       1   22        0                     0  39.108252 -123.645121
# 4834       1   21        1                     0  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months  \
# 0                       2                 9
# ...

# %%
X=df.drop('Customer Status',axis=1)

# %%
X.head()
# Out:
#    Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0       0   37        1                     0  34.827662 -118.999073
# 1       1   46        0                     0  34.162515 -118.203869
# 2       1   50        0                     0  33.645672 -117.922613
# 3       1   78        1                     0  38.014457 -122.115432
# 4       0   75        1                     0  34.227846 -119.079903
#
#    Number of Referrals  Tenure in Months  Avg Monthly Long Distance Charges  \
# 0                    2                 9                              42.39
# 1                    0                 9                              10.69
# 2                    0                 4                              33.65
# 3                    1                13                              27.82
# 4                    3                 3                               7.38
#
#    Multiple Lines  ...  Unlimited Data  Contract  Paperless Billing  \
# ...

# %%
y=df['Customer Status']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Customer Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (3868, 29)
# (3868,)

# %%
from scipy import stats
import numpy as np

# %%
selected_columns=["Number of Dependents","Avg Monthly GB Download","Total Refunds","Total Extra Data Charges",
        "Total Long Distance Charges","Total Revenue"]
z_score=np.abs(stats.zscore(X_train[selected_columns]))
threshold=2.5
outlier_indices=np.where(z_score > threshold)[0]
X_train=X_train.drop(X_train.index[outlier_indices])
y_train=y_train.drop(y_train.index[outlier_indices])

# %%
X_train.head()
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 432        1   31        0                     0  33.977468 -118.445475
# 4135       1   21        1                     0  33.723579 -118.005441
# 289        1   41        0                     1  34.007353 -118.033683
# 2692       0   42        1                     0  37.441931 -121.878502
# 4110       0   32        1                     0  33.324900 -114.758334
#
#       Number of Referrals  Tenure in Months  \
# 432                     0                56
# 4135                    4                66
# 289                     0                12
# 2692                    1                69
# 4110                    0                57
#
#       Avg Monthly Long Distance Charges  Multiple Lines  ...  Unlimited Data  \
# 432                               37.99               1  ...               1
# 4135                               7.67               1  ...               1
# ...

# %%
y_train.head()
# Out:
# 432     1
# 4135    1
# 289     1
# 2692    0
# 4110    1
# Name: Customer Status, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
Logr=LogisticRegression()
model=Logr.fit(X_train,y_train)
model
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)
y_pred[:5]
# Out:
# array([1, 1, 1, 0, 1], dtype=int64)

# %%
print(y_pred[:5])
print(y_test[:5])
# Out:
# [1 1 1 0 1]
# 3317    0
# 2533    1
# 1041    1
# 3307    0
# 4401    0
# Name: Customer Status, dtype: int64

# %%
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7528438469493278

# %%
import math

# %%
RMSE=math.sqrt(mean_squared_error(y_test,y_pred))

# %%
from sklearn.metrics import f1_score

# %%
print(f'accuracy_score: {acc}')
print(f'precision score: {precision_score(y_test,y_pred)}')
print(f'recall score: {recall_score(y_test,y_pred)}')
print(f'mean absolute error: {mean_absolute_error(y_test,y_pred)}')
print(f'R2_score: {r2_score(y_test,y_pred)}')
print(f'mean squared error: {mean_squared_error(y_test,y_pred)}')
print(f'root mean squared error: {RMSE}')
print(f'F1score:{f1_score(y_test,y_pred)}')
# Out:
# accuracy_score: 0.7528438469493278
# precision score: 0.8067484662576687
# recall score: 0.8231611893583725
# mean absolute error: 0.24715615305067218
# R2_score: -0.10268044581854263
# mean squared error: 0.24715615305067218
# root mean squared error: 0.4971480192565109
# F1score:0.814872192099148

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[202, 126],
#        [113, 526]], dtype=int64)

# %%
ConfusionMatrixDisplay(cm,display_labels=[False,True]).plot()
plt.grid(False)

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_pred).ravel()
print(tn,tp,fp,fn)
# Out:
# 202 526 126 113

# %%
print(f'tp:{tp}')
print(f'fp:{fp}')
print(f'tn:{tn}')
print(f'fn:{fn}')
# Out:
# tp:526
# fp:126
# tn:202
# fn:113

# %%
accuracy=(tp+tn)/(tp+tn+fn+fp)
precision=tp/(tp+fp)
recall=tp/(tp+fn)
f1score=2*precision*recall/(precision+recall)

# %%
y_pred_prob=model.predict_proba(X_test)[:,1]
y_pred_prob
# Out:
# array([0.68115236, 0.60631356, 0.97623966, 0.26557481, 0.6129041 ,
#        0.25078947, 0.54932997, 0.69700606, 0.23911896, 0.53685785,
#        0.37738021, 0.41966531, 0.64571648, 0.48171434, 0.64048776,
#        0.92315485, 0.78349604, 0.51936428, 0.97394456, 0.24989987,
#        0.49848843, 0.21781438, 0.45189335, 0.83700299, 0.18840277,
#        0.33578018, 0.35702122, 0.43663524, 0.35391299, 0.56892507,
#        0.4102885 , 0.84173174, 0.5797152 , 0.56702842, 0.7617741 ,
#        0.6354413 , 0.97849871, 0.602401  , 0.53213867, 0.69779788,
#        0.62888047, 0.69089646, 0.72949956, 0.41492156, 0.8625874 ,
#        0.8556787 , 0.82504915, 0.95409579, 0.59484691, 0.92979878,
#        0.34432657, 0.49512291, 0.78333014, 0.90582354, 0.21102072,
#        0.97361794, 0.33894189, 0.46197589, 0.51241157, 0.45294432,
#        0.85066669, 0.80572621, 0.51489141, 0.79027869, 0.41645856,
#        0.2269539 , 0.29451195, 0.4723616 , 0.92032784, 0.2699328 ,
# ...

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)

# %%
plt.plot(fpr,tpr)

# %% [markdown]
# # KNN

# %%
df=pd.read_csv("preprocessed_data.csv")
df
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0          0   37        1                     0  34.827662 -118.999073
# 1          1   46        0                     0  34.162515 -118.203869
# 2          1   50        0                     0  33.645672 -117.922613
# 3          1   78        1                     0  38.014457 -122.115432
# 4          0   75        1                     0  34.227846 -119.079903
# ...      ...  ...      ...                   ...        ...         ...
# 4830       0   53        0                     0  36.807595 -118.901544
# 4831       0   20        0                     0  32.759327 -116.997260
# 4832       1   40        1                     0  37.734971 -120.954271
# 4833       1   22        0                     0  39.108252 -123.645121
# 4834       1   21        1                     0  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months  \
# 0                       2                 9
# ...

# %%
X=df.drop(columns=['Customer Status'])
X.head()
# Out:
#    Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0       0   37        1                     0  34.827662 -118.999073
# 1       1   46        0                     0  34.162515 -118.203869
# 2       1   50        0                     0  33.645672 -117.922613
# 3       1   78        1                     0  38.014457 -122.115432
# 4       0   75        1                     0  34.227846 -119.079903
#
#    Number of Referrals  Tenure in Months  Avg Monthly Long Distance Charges  \
# 0                    2                 9                              42.39
# 1                    0                 9                              10.69
# 2                    0                 4                              33.65
# 3                    1                13                              27.82
# 4                    3                 3                               7.38
#
#    Multiple Lines  ...  Unlimited Data  Contract  Paperless Billing  \
# ...

# %%
y=df['Customer Status']
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Customer Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (3868, 29)
# (3868,)

# %%
X_train.head()
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 432        1   31        0                     0  33.977468 -118.445475
# 4135       1   21        1                     0  33.723579 -118.005441
# 289        1   41        0                     1  34.007353 -118.033683
# 2692       0   42        1                     0  37.441931 -121.878502
# 4110       0   32        1                     0  33.324900 -114.758334
#
#       Number of Referrals  Tenure in Months  \
# 432                     0                56
# 4135                    4                66
# 289                     0                12
# 2692                    1                69
# 4110                    0                57
#
#       Avg Monthly Long Distance Charges  Multiple Lines  ...  Unlimited Data  \
# 432                               37.99               1  ...               1
# 4135                               7.67               1  ...               1
# ...

# %%
y_train.head()
# Out:
# 432     1
# 4135    1
# 289     1
# 2692    0
# 4110    1
# Name: Customer Status, dtype: int64

# %% [markdown]
# # Outlier removal

# %%
from scipy import stats

# %%
selected_columns=["Number of Dependents","Avg Monthly GB Download","Total Refunds","Total Extra Data Charges",
        "Total Long Distance Charges","Total Revenue"]
z_score=np.abs(stats.zscore(X_train[selected_columns]))
threshold=3.0
outlier_indices=np.where(z_score > threshold)[0]
X_train=X_train.drop(X_train.index[outlier_indices]).reset_index(drop=True)
y_train=y_train.drop(y_train.index[outlier_indices]).reset_index(drop=True)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn=KNeighborsClassifier()
model=kn.fit(X_train,y_train)
model
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(X_test)
y_pred[:5]
# Out:
# array([1, 1, 1, 0, 1], dtype=int64)

# %%
y_test[:5]
# Out:
# 3317    0
# 2533    1
# 1041    1
# 3307    0
# 4401    0
# Name: Customer Status, dtype: int64

# %%
import math

# %%
RMSE=math.sqrt(mean_squared_error(y_test,y_pred))
RMSE
# Out:
# 0.515529265892565

# %%
print(f'mean squared error:{mean_squared_error(y_test,y_pred)}')
print(f'Root mean squared error: {RMSE}')
print(f'mean absolute error:{mean_absolute_error(y_test,y_pred)}')
print(f'R2-score:{r2_score(y_test,y_pred)}')
print(f'accuracy:{accuracy_score(y_test,y_pred)}')
print(f'precision:{precision_score(y_test,y_pred)}')
print(f'Recall:{recall_score(y_test,y_pred)}')
print(f'f1_score:{f1_score(y_test,y_pred)}')
# Out:
# mean squared error:0.265770423991727
# Root mean squared error: 0.515529265892565
# mean absolute error:0.265770423991727
# R2-score:-0.1857275086835375
# accuracy:0.734229576008273
# precision:0.7720797720797721
# Recall:0.8482003129890454
# f1_score:0.808351976137211

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred)
ConfusionMatrixDisplay(cm,display_labels=[False,True]).plot()
plt.grid(False)

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_pred).ravel()

# %%
print(f'tn:{tn}')
print(f'tp:{tp}')
print(f'fn:{fn}')
print(f'fp:{fp}')
# Out:
# tn:168
# tp:542
# fn:97
# fp:160

# %%
accuracy=(tp+tn)/(tp+tn+fp+fn)
precision=tp/(tp+fp)
recall=tp/(tp+fn)
f1_score=(2*precision*recall)/(precision+recall)

# %%
y_pred_prob=model.predict_proba(X_test)[:,1]

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)

# %%
plt.plot(fpr,tpr)

# %% [markdown]
# ## Random forest

# %%
df=pd.read_csv("preprocessed_data.csv")
df
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0          0   37        1                     0  34.827662 -118.999073
# 1          1   46        0                     0  34.162515 -118.203869
# 2          1   50        0                     0  33.645672 -117.922613
# 3          1   78        1                     0  38.014457 -122.115432
# 4          0   75        1                     0  34.227846 -119.079903
# ...      ...  ...      ...                   ...        ...         ...
# 4830       0   53        0                     0  36.807595 -118.901544
# 4831       0   20        0                     0  32.759327 -116.997260
# 4832       1   40        1                     0  37.734971 -120.954271
# 4833       1   22        0                     0  39.108252 -123.645121
# 4834       1   21        1                     0  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months  \
# 0                       2                 9
# ...

# %%
X=df.drop('Customer Status',axis=1)
X.head()
# Out:
#    Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0       0   37        1                     0  34.827662 -118.999073
# 1       1   46        0                     0  34.162515 -118.203869
# 2       1   50        0                     0  33.645672 -117.922613
# 3       1   78        1                     0  38.014457 -122.115432
# 4       0   75        1                     0  34.227846 -119.079903
#
#    Number of Referrals  Tenure in Months  Avg Monthly Long Distance Charges  \
# 0                    2                 9                              42.39
# 1                    0                 9                              10.69
# 2                    0                 4                              33.65
# 3                    1                13                              27.82
# 4                    3                 3                               7.38
#
#    Multiple Lines  ...  Unlimited Data  Contract  Paperless Billing  \
# ...

# %%
y=df['Customer Status']
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Customer Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X_train.head()
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 432        1   31        0                     0  33.977468 -118.445475
# 4135       1   21        1                     0  33.723579 -118.005441
# 289        1   41        0                     1  34.007353 -118.033683
# 2692       0   42        1                     0  37.441931 -121.878502
# 4110       0   32        1                     0  33.324900 -114.758334
#
#       Number of Referrals  Tenure in Months  \
# 432                     0                56
# 4135                    4                66
# 289                     0                12
# 2692                    1                69
# 4110                    0                57
#
#       Avg Monthly Long Distance Charges  Multiple Lines  ...  Unlimited Data  \
# 432                               37.99               1  ...               1
# 4135                               7.67               1  ...               1
# ...

# %%
y_train.head()
# Out:
# 432     1
# 4135    1
# 289     1
# 2692    0
# 4110    1
# Name: Customer Status, dtype: int64

# %% [markdown]
# # Outlier removal

# %%
from scipy import stats

# %%
selected_columns=["Number of Dependents","Avg Monthly GB Download","Total Refunds","Total Extra Data Charges",
        "Total Long Distance Charges","Total Revenue"]
z_score=np.abs(stats.zscore(X_train[selected_columns]))
threshold=2.5
outlier_indices=np.where(z_score > threshold)[0]
X_train=X_train.drop(X_train.index[outlier_indices])
y_train=y_train.drop(y_train.index[outlier_indices])

# %%
X_train.head()
# Out:
#       Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 432        1   31        0                     0  33.977468 -118.445475
# 4135       1   21        1                     0  33.723579 -118.005441
# 289        1   41        0                     1  34.007353 -118.033683
# 2692       0   42        1                     0  37.441931 -121.878502
# 4110       0   32        1                     0  33.324900 -114.758334
#
#       Number of Referrals  Tenure in Months  \
# 432                     0                56
# 4135                    4                66
# 289                     0                12
# 2692                    1                69
# 4110                    0                57
#
#       Avg Monthly Long Distance Charges  Multiple Lines  ...  Unlimited Data  \
# 432                               37.99               1  ...               1
# 4135                               7.67               1  ...               1
# ...

# %%
y_train.head()
# Out:
# 432     1
# 4135    1
# 289     1
# 2692    0
# 4110    1
# Name: Customer Status, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
model=rf.fit(X_train,y_train)
model
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(X_test)
y_pred[:5]
# Out:
# array([1, 0, 1, 0, 1], dtype=int64)

# %%
y_test[:5]
# Out:
# 3317    0
# 2533    1
# 1041    1
# 3307    0
# 4401    0
# Name: Customer Status, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,f1_score,accuracy_score,precision_score,recall_score

# %%
Rmse=math.sqrt(mean_squared_error(y_test,y_pred))

# %%
print(f'Accuracy:{accuracy_score(y_test,y_pred)}')
print(f'precision:{precision_score(y_test,y_pred)}')
print(f'recall:{recall_score(y_test,y_pred)}')
print(f'f1 score:{f1_score(y_test,y_pred)}')
print(f'mean squared error:{mean_squared_error(y_test,y_pred)}')
print(f'root mean squared error:{Rmse}')
print(f'mean absolute error:{mean_absolute_error(y_test,y_pred)}')
print(f'R2_score:{r2_score(y_test,y_pred)}')
# Out:
# Accuracy:0.8045501551189245
# precision:0.8279883381924198
# recall:0.8888888888888888
# f1 score:0.8573584905660377
# mean squared error:0.1954498448810755
# root mean squared error:0.44209709892859
# mean absolute error:0.1954498448810755
# R2_score:0.1280058399175542

# %%
from sklearn.metrics import confusion_matrix,roc_curve,ConfusionMatrixDisplay

# %%
y_pred_prob=model.predict_proba(X_test)[:,1]

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)

# %%
plt.plot(fpr,tpr)

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_pred).ravel()

# %%
print(f'tn: {tn}')
print(f'fp: {fp}')
print(f'fn: {fn}')
print(f'tp: {tp}')
# Out:
# tn: 210
# fp: 118
# fn: 71
# tp: 568

# %%
Cmt=confusion_matrix(y_test,y_pred)
cmt
# Out:
# array([[215, 113],
#        [127, 512]], dtype=int64)

# %%
ConfusionMatrixDisplay(cmt,
                      display_labels=[False,True]).plot()
plt.grid(False)
